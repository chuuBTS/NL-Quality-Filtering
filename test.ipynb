# %%
import openai # type: ignore
openai.api_base = 'https://gpt-api.hkust-gz.edu.cn/v1'
openai.api_key = "736096cf53d34617afb48933d78d7c405420d6b8e6804e819622b4f2d2091d8c"

# %%
# 定义消息
messages = [
    {"role": "system", "content": "你是一个有帮助的助手。"},
    {"role": "user", "content": "你好，我有一只呆河马。"}
]
 
# 调用 ChatCompletion API
response = openai.ChatCompletion.create(
    model="gpt-4",  # 或者 "gpt-3.5-turbo"
    messages=messages,
    max_tokens=100,
    temperature=0.7
)
 
# 打印响应文本
print(response.choices[0].message['content'].strip())
# Out:
# 你好！呆河马是一种非常可爱的宝可梦。你是想了解一些关于呆河马的养成技巧，还是想知道更多关于它的信息呢？

# %%
# 调用 Completion API
response = openai.Completion.create(
    model="text-davinci-003",
    prompt="你好，我有一只呆河马",
    max_tokens=100,
    temperature=0.7
)
 
# 打印响应文本
print(response.choices[0].text.strip())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\chuu_local\.conda\envs\generate-nl-env\lib\site-packages\openai\openai_object.py:59, in OpenAIObject.__getattr__(self, k)
#      58 try:
# ---> 59     return self[k]
#      60 except KeyError as err:
#
# KeyError: 'choices'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 10
#       2 response = openai.Completion.create(
#       3     model="text-davinci-003",
#       4     prompt="你好，我有一只呆河马",
#       5     max_tokens=100,
#       6     temperature=0.7
#       7 )
#       9 # 打印响应文本
# ---> 10 print(response.choices[0].text.strip())
#
# File c:\Users\chuu_local\.conda\envs\generate-nl-env\lib\site-packages\openai\openai_object.py:61, in OpenAIObject.__getattr__(self, k)
# ...

# %%
response = openai.Completion.create(
    engine="gpt-3.5-turbo",
    prompt="Hello, how are you?",
    max_tokens=50,
    stop=None,
    temperature=0.5,
)

print(response)
print(response.choices[0].text)
# Out:
# {
#   "code": 401,
#   "msg": "Unauthorized"
# }
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\chuu_local\.conda\envs\generate-nl-env\lib\site-packages\openai\openai_object.py:59, in OpenAIObject.__getattr__(self, k)
#      58 try:
# ---> 59     return self[k]
#      60 except KeyError as err:
#
# KeyError: 'choices'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 10
#       1 response = openai.Completion.create(
#       2     engine="gpt-3.5-turbo",
#       3     prompt="Hello, how are you?",
#    (...)
#       6     temperature=0.5,
#       7 )
#       9 print(response)
# ---> 10 print(response.choices[0].text)
#
# ...

# %%
chuu ={
    "vl_0265_combi_23.json": {
        "nl_type": "command"
    },
    "vl_0265_combi_3.json": {
        "nl_type": "question",
        "charts": {
            "1": {
                "chart_quality": "poor",
                "error_type": [
                    "duplicate"
                ]
            },
            "0": {
                "chart_quality": "good",
                "error_type": []
            },
            "2": {
                "chart_quality": "good",
                "error_type": []
            },
            "3": {
                "chart_quality": "poor",
                "error_type": [
                    "duplicate"
                ]
            },
            "4": {
                "chart_quality": "good",
                "error_type": []
            },
            "5": {
                "chart_quality": "good",
                "error_type": []
            },
            "6": {
                "chart_quality": "good",
                "error_type": []
            }
        }
    },
    "vl_0265_combi_4.json": {
        "nl_type": "question"
    }
}

# %%
# 定义文件路径
file_path = 'data/merged_result.json'

# 读取filtered_chart_types_result.json文件
import json

with open(file_path, 'r') as f:
    filtered_data = json.load(f)

# 获取文件中的键值对数量
num_entries = len(filtered_data)

print(f"{file_path} 文件中共有 {num_entries} 个键值对")
# Out:
# data/merged_result.json 文件中共有 7434 个键值对

# %%
import spacy

# 加载预训练的英语模型
nlp = spacy.load("en_core_web_sm")

# 输入句子
sentence = "What trends can be observed in the rents over the years from 2010 to 2020?"

# 处理句子
doc = nlp(sentence)

# 输出词性标注和依赖关系
for token in doc:
    print(f"Word: {token.text}, POS: {token.pos_}, Dependency: {token.dep_}, Head: {token.head.text}")

# 输出依赖树
spacy.displacy.render(doc, style="dep", jupyter=True)
# Out:
# Word: What, POS: DET, Dependency: det, Head: trends
# Word: trends, POS: NOUN, Dependency: nsubjpass, Head: observed
# Word: can, POS: AUX, Dependency: aux, Head: observed
# Word: be, POS: AUX, Dependency: auxpass, Head: observed
# Word: observed, POS: VERB, Dependency: ROOT, Head: observed
# Word: in, POS: ADP, Dependency: prep, Head: observed
# Word: the, POS: DET, Dependency: det, Head: rents
# Word: rents, POS: NOUN, Dependency: pobj, Head: in
# Word: over, POS: ADP, Dependency: prep, Head: observed
# Word: the, POS: DET, Dependency: det, Head: years
# Word: years, POS: NOUN, Dependency: pobj, Head: over
# Word: from, POS: ADP, Dependency: prep, Head: years
# Word: 2010, POS: NUM, Dependency: pobj, Head: from
# Word: to, POS: ADP, Dependency: prep, Head: from
# Word: 2020, POS: NUM, Dependency: pobj, Head: to
# Word: ?, POS: PUNCT, Dependency: punct, Head: observed
# ...

# %%
import os
import json

# 定义文件夹路径
folder_path = 'selected_constraint'

# 初始化计数器
list_field_count = 0
total_files = 0

# 遍历文件夹中的所有json文件
for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        total_files += 1
        file_path = os.path.join(folder_path, filename)
        
        with open(file_path, 'r') as file:
            data = json.load(file)
            fields_info = data.get('encoded_fields', [])
            
            # 检查fields_info中的字段类型
            for field in fields_info:
                if field.get('type') == 'list':
                    list_field_count += 1

# 计算占比
if total_files > 0:
    proportion = (list_field_count / total_files) * 100
else:
    proportion = 0

print(f"总文件数: {total_files}, list类型字段数量: {list_field_count}, 占比: {proportion:.2f}%")
# Out:
# 总文件数: 8458, list类型字段数量: 0, 占比: 0.00%
